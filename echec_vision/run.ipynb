# %%
# %run main.py
# Out:
# [lines] [[[ 6.6600000e+02  1.5009831e+00]]
#
#  [[-3.8800000e+02  3.0194197e+00]]
#
#  [[ 2.8400000e+02  5.2359879e-02]]
#
#  [[ 3.5800000e+02  1.5184364e+00]]
#
#  [[-4.4400000e+02  2.9146998e+00]]
#
#  [[-3.3700000e+02  3.1066861e+00]]
#
#  [[ 2.1600000e+02  1.5707964e-01]]
#
#  [[ 3.1000000e+02  1.5184364e+00]]
#
#  [[ 4.1100000e+02  1.5184364e+00]]
#
#  [[ 2.5300000e+02  8.7266460e-02]]
#
#  [[ 2.6600000e+02  1.5184364e+00]]
#
#  [[ 3.0700000e+02  0.0000000e+00]]
#
#  [[ 5.4400000e+02  1.5009831e+00]]
#
#  [[-4.1600000e+02  2.9845130e+00]]
#
#  [[ 4.7100000e+02  1.5184364e+00]]
#
#  [[ 2.2800000e+02  1.3962634e-01]]
#
#  [[-4.3400000e+02  2.9321532e+00]]
#
#  [[-3.6000000e+02  3.0543261e+00]]
#
#  [[ 2.2700000e+02  1.5184364e+00]]
#
#  [[ 6.2000000e+02  1.5009831e+00]]]
# [  0 114 193 273 352 431 509 588 666 700]
# S : 0
# rlt_points [  0 114 193 273 352 431 509 588 666 700]
# rlt_points roll [700   0 114 193 273 352 431 509 588 666]
# rlt_points_ect [114  79  80  79  79  78  79  78  34]
# ect_median 79.0
# ect_norm [1.44303797 1.         1.01265823 1.         1.         0.98734177
#  1.         0.98734177 0.43037975]
# ect_norm_rst [0.44303797 0.         0.01265823 0.         0.         0.98734177
#  0.         0.98734177 0.43037975]
# ect_norm_divisor [1 1 1 1 1 0 1 0 0]
# mask_remove [ True False False False False False False False  True]
# ect_norm_divisor with added case [0 1 1 1 1 1 1 1 0]
# S : 114
# rlt_points [  0  79 159 238 317 395 474 552 586]
# rlt_points roll [586   0  79 159 238 317 395 474 552]
# rlt_points_ect [79 80 79 79 78 79 78 34]
# ect_median 79.0
# ect_norm [1.         1.01265823 1.         1.         0.98734177 1.
#  0.98734177 0.43037975]
# ect_norm_rst [0.         0.01265823 0.         0.         0.98734177 0.
#  0.98734177 0.43037975]
# ect_norm_divisor [1 1 1 1 0 1 0 0]
# mask_remove [False False False False False False False  True]
# ect_norm_divisor with added case [1 1 1 1 1 1 1 0]
# S : 193
# rlt_points [  0  80 159 238 316 395 473 507]
# rlt_points roll [507   0  80 159 238 316 395 473]
# rlt_points_ect [80 79 79 78 79 78 34]
# ect_median 79.0
# ect_norm [1.01265823 1.         1.         0.98734177 1.         0.98734177
#  0.43037975]
# ect_norm_rst [0.01265823 0.         0.         0.98734177 0.         0.98734177
#  0.43037975]
# ect_norm_divisor [1 1 1 0 1 0 0]
# mask_remove [False False False False False False  True]
# ect_norm_divisor with added case [1 1 1 1 1 1 0]
# S : 273
# rlt_points [  0  79 158 236 315 393 427]
# rlt_points roll [427   0  79 158 236 315 393]
# rlt_points_ect [79 79 78 79 78 34]
# ect_median 78.5
# ect_norm [1.00636943 1.00636943 0.99363057 1.00636943 0.99363057 0.43312102]
# ect_norm_rst [0.00636943 0.00636943 0.99363057 0.00636943 0.99363057 0.43312102]
# ect_norm_divisor [1 1 0 1 0 0]
# mask_remove [False False False False False  True]
# ect_norm_divisor with added case [1 1 1 1 1 0]
# S : 352
# rlt_points [  0  79 157 236 314 348]
# rlt_points roll [348   0  79 157 236 314]
# rlt_points_ect [79 78 79 78 34]
# ect_median 78.0
# ect_norm [1.01282051 1.         1.01282051 1.         0.43589744]
# ect_norm_rst [0.01282051 0.         0.01282051 0.         0.43589744]
# ect_norm_divisor [1 1 1 1 0]
# mask_remove [False False False False  True]
# ect_norm_divisor with added case [1 1 1 1 0]
# S : 431
# rlt_points [  0  78 157 235 269]
# rlt_points roll [269   0  78 157 235]
# rlt_points_ect [78 79 78 34]
# ect_median 78.0
# ect_norm [1.         1.01282051 1.         0.43589744]
# ect_norm_rst [0.         0.01282051 0.         0.43589744]
# ect_norm_divisor [1 1 1 0]
# mask_remove [False False False  True]
# ect_norm_divisor with added case [1 1 1 0]
# S : 509
# rlt_points [  0  79 157 191]
# rlt_points roll [191   0  79 157]
# rlt_points_ect [79 78 34]
# ect_median 78.0
# ect_norm [1.01282051 1.         0.43589744]
# ect_norm_rst [0.01282051 0.         0.43589744]
# ect_norm_divisor [1 1 0]
# mask_remove [False False  True]
# ect_norm_divisor with added case [1 1 0]
# S : 588
# rlt_points [  0  78 112]
# rlt_points roll [112   0  78]
# rlt_points_ect [78 34]
# ect_median 56.0
# ect_norm [1.39285714 0.60714286]
# ect_norm_rst [0.39285714 0.60714286]
# ect_norm_divisor [1 0]
# mask_remove [ True  True]
# ect_norm_divisor with added case [0 0]
# S : 666
# rlt_points [ 0 34]
# rlt_points roll [34  0]
# rlt_points_ect [34]
# ect_median 34.0
# ect_norm [1.]
# ect_norm_rst [0.]
# ect_norm_divisor [1]
# mask_remove [False]
# ect_norm_divisor with added case [1]
# ---- get_interpolate_coord ----
# Nbr de case : 1 Idx : 0
# current_idx 1
# current_point 193
# Nbr de case : 1 Idx : 1
# current_idx 2
# current_point 273
# Nbr de case : 1 Idx : 2
# current_idx 3
# current_point 352
# Nbr de case : 1 Idx : 3
# current_idx 4
# current_point 431
# Nbr de case : 1 Idx : 4
# current_idx 5
# current_point 509
# Nbr de case : 1 Idx : 5
# current_idx 6
# current_point 588
# Nbr de case : 1 Idx : 6
# current_idx 7
# current_point 666
# Nbr de case : 0 Idx : 7
# [  0 371 464 556 649 700]
# S : 0
# rlt_points [  0 371 464 556 649 700]
# rlt_points roll [700   0 371 464 556 649]
# rlt_points_ect [371  93  92  93  51]
# ect_median 93.0
# ect_norm [3.98924731 1.         0.98924731 1.         0.5483871 ]
# ect_norm_rst [0.98924731 0.         0.98924731 0.         0.5483871 ]
# ect_norm_divisor [3 1 0 1 0]
# mask_remove [False False False False  True]
# ect_norm_divisor with added case [4 1 1 1 0]
# S : 371
# rlt_points [  0  93 185 278 329]
# rlt_points roll [329   0  93 185 278]
# rlt_points_ect [93 92 93 51]
# ect_median 92.5
# ect_norm [1.00540541 0.99459459 1.00540541 0.55135135]
# ect_norm_rst [0.00540541 0.99459459 0.00540541 0.55135135]
# ect_norm_divisor [1 0 1 0]
# mask_remove [False False False  True]
# ect_norm_divisor with added case [1 1 1 0]
# S : 464
# rlt_points [  0  92 185 236]
# rlt_points roll [236   0  92 185]
# rlt_points_ect [92 93 51]
# ect_median 92.0
# ect_norm [1.         1.01086957 0.55434783]
# ect_norm_rst [0.         0.01086957 0.55434783]
# ect_norm_divisor [1 1 0]
# mask_remove [False False  True]
# ect_norm_divisor with added case [1 1 0]
# S : 556
# rlt_points [  0  93 144]
# rlt_points roll [144   0  93]
# rlt_points_ect [93 51]
# ect_median 72.0
# ect_norm [1.29166667 0.70833333]
# ect_norm_rst [0.29166667 0.70833333]
# ect_norm_divisor [1 0]
# mask_remove [ True  True]
# ect_norm_divisor with added case [0 0]
# S : 649
# rlt_points [ 0 51]
# rlt_points roll [51  0]
# rlt_points_ect [51]
# ect_median 51.0
# ect_norm [1.]
# ect_norm_rst [0.]
# ect_norm_divisor [1]
# mask_remove [False]
# ect_norm_divisor with added case [1]
# ---- get_interpolate_coord ----
# Nbr de case : 4 Idx : 0
# current_idx 0
# current_point 371
# 0.25
# previous_point 700
# distance -329
# 0.5
# previous_point 700
# distance -329
# 0.75
# previous_point 700
# distance -329
# 1.0
# previous_point 700
# distance -329
# Nbr de case : 1 Idx : 1
# current_idx 1
# current_point 464
# Nbr de case : 1 Idx : 2
# current_idx 2
# current_point 556
# Nbr de case : 1 Idx : 3
# current_idx 3
# current_point 649
# Nbr de case : 0 Idx : 4
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\DataScience\Echecs Vision\echec_vision\main.py in <module>
#      60
#      61 if __name__ == "__main__":
# ---> 62     main("C:/Users/Romaric/chess_data/render/train/0002.png")
#      63
#      64 # W : White
#
# ~\DataScience\Echecs Vision\echec_vision\main.py in main(image_path)
#      37     for i in range(0, 8):
#      38         for j in range(0, 8):
# ---> 39             case = chess_plate.get_case(i, j)
#      40             case_sobel = chess_plate.get_case_on_img(sobel_8u, i, j)
#      41
#
# ~\DataScience\Echecs Vision\echec_vision\classes\chess_plate.py in get_case(self, i, j)
#      43
#      44     def get_case(self, i,j):
# ---> 45         return self.get_case_on_img(self.plate_img, i,j)
#      46
#      47     def get_case_on_img(self, img, i,j):
#
# ~\DataScience\Echecs Vision\echec_vision\classes\chess_plate.py in get_case_on_img(self, img, i, j)
#      52
#      53         case = img[x1:x2, y1:y2]
# ---> 54         return resize_img(case, 200)
#
# ~\DataScience\Echecs Vision\echec_vision\functions\resize_img.py in resize_img(img, size)
#       6     dim = (width, height)
#       7
# ----> 8     return cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
#       9
#      10 def image_resize(image, width = None, height = None, inter = cv2.INTER_AREA):
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
a = np.array([100, 100])

# %%
a / 2
# Out:
# array([50., 50.])

# %%
import numpy as np
import cv2 as cv2

import time
import os
import numpy as np
import cv2 as cv2
import chess.engine
from matplotlib import pyplot as plt
from get_chess_plate import *
from scipy import signal
from skimage.metrics import structural_similarity
from classes.game import *
from classes.video_capture import *
from classes.image_logger import *

# %%
frame = cv2.imread(
        "C:/Users/Romaric/DataScience/Echecs Vision/echec_vision/images/Suivis 2/9.jpg")

# %%
plate = get_chess_plate(frame)
plate.show()
cv2.waitKey(0)
# Out:
# -1

# %%
a = [600, 678, 56, 789, 602, 567, 678]

# %%
b = [np.array([[35, 67]]), np.array([[37, 12]]), np.array([[45, 89]]), np.array([[32, 56]]), np.array([[13, 54]]), np.array([[25, 24]]), np.array([[25, 64]])]

# %%
sorted(zip(a,b))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13632\3653478187.py in <module>
# ----> 1 sorted(zip(a,b))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
